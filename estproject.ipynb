# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !git clone https://github.com/jainbhavya2005/blood-classification-ai
# %cd blood-classification-ai
# Out:
# Cloning into 'blood-classification-ai'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 12 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 10.99 KiB | 10.99 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/blood-classification-ai/scripts/blood-classification-ai

# %%
# !pip install numpy opencv-python scikit-learn tensorflow matplotlib seaborn

# %%
# !pip install kaggle

# %%
# !pip install kagglehub

# %%
import kagglehub

path = kagglehub.dataset_download("iarunava/cell-images-for-detecting-malaria")

print("Path:", path)
# Out:
# Using Colab cache for faster access to the 'cell-images-for-detecting-malaria' dataset.
# Path: /kaggle/input/cell-images-for-detecting-malaria

# %%
# !ls $path
# Out:
# cell_images

# %%
# !mkdir dataset
# !cp -r $path/cell_images/Parasitized dataset/infected
# !cp -r $path/cell_images/Uninfected dataset/healthy

# %%
# !ls dataset
# Out:
# healthy  infected

# %%
# !rm -rf dataset
# !mkdir dataset
# !cp -r $path/cell_images/Parasitized dataset/infected
# !cp -r $path/cell_images/Uninfected dataset/healthy

# %%
# !ls dataset/infected | wc -l
# !ls dataset/healthy | wc -l
# Out:
# 13780
# 13780

# %%
# %cd scripts
# !python train.py
# Out:
# /content/blood-classification-ai/scripts/blood-classification-ai/scripts
# 2026-04-26 07:32:41.815825: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777188761.836422   13092 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777188761.843089   13092 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777188761.859863   13092 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
